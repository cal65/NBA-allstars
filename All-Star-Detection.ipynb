# %%
import pandas as pd
import numpy as np
import random

# %%
season_stats = pd.read_csv('Seasons_Stats.csv')
all_stars = pd.read_csv('allstars.csv')

# %% [markdown]
# ## Season_stats comes from https://www.kaggle.com/drgilermo/nba-players-stats

# %%
season_stats.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...    0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...    0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...    0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...    0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...    0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %% [markdown]
# # all star data comes from https://data.world/datasets/nba and includes 2000-2016

# %%
all_stars.head()
# Out:
#      Year         Player Pos    HT     WT                   Team  \
# 0  2016.0  Stephen Curry   G   6-3  190.0  Golden State Warriors
# 1  2016.0   James Harden  SG   6-5  220.0        Houston Rockets
# 2  2016.0   Kevin Durant  SF   6-9  240.0  Golden State Warriors
# 3  2016.0  Kawhi Leonard   F   6-7  230.0      San Antonio Spurs
# 4  2016.0  Anthony Davis  PF  6-11  253.0   New Orleans Pelicans
#
#                         Selection Type    NBA Draft Status    Nationality  \
# 0  Western All-Star Fan Vote Selection   2009 Rnd 1 Pick 7  United States
# 1  Western All-Star Fan Vote Selection   2009 Rnd 1 Pick 3  United States
# 2  Western All-Star Fan Vote Selection   2007 Rnd 1 Pick 2  United States
# 3  Western All-Star Fan Vote Selection  2011 Rnd 1 Pick 15  United States
# 4  Western All-Star Fan Vote Selection   2012 Rnd 1 Pick 1  United States
#
#    Unnamed: 9     ...       Unnamed: 15  Unnamed: 16  Unnamed: 17  \
# 0         NaN     ...               NaN          NaN          NaN
# 1         NaN     ...               NaN          NaN          NaN
# 2         NaN     ...               NaN          NaN          NaN
# 3         NaN     ...               NaN          NaN          NaN
# 4         NaN     ...               NaN          NaN          NaN
#
#    Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 23  Unnamed: 24
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#
# [5 rows x 25 columns]

# %%
[season_stats.shape, all_stars.shape]
# Out:
# [(24691, 53), (998, 25)]

# %%
all_stars.columns
# Out:
# Index(['Year', 'Player', 'Pos', 'HT', 'WT', 'Team', 'Selection Type',
#        'NBA Draft Status', 'Nationality', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24'],
#       dtype='object')

# %%
# Some extra columns were accidentally brought over in excel conversion. Programmatically get rid of them
real_cols = [s for s in all_stars.columns if 'Unnamed' not in s]

# %%
all_stars = all_stars[real_cols] #get rid of unnecessary columns

# %%
all_stars = all_stars[all_stars.Player.notnull()]

# %%
all_stars['Player']
# Out:
# 0              Stephen Curry
# 1               James Harden
# 2               Kevin Durant
# 3              Kawhi Leonard
# 4              Anthony Davis
# 5          Russell Westbrook
# 6           DeMarcus Cousins
# 7              Klay Thompson
# 8             Draymond Green
# 9                 Marc Gasol
# 10            DeAndre Jordan
# 11            Gordon Hayward
# 12              Kyrie Irving
# 13             DeMar DeRozan
# 14              LeBron James
# 15     Giannis Antetokounmpo
# 16              Jimmy Butler
# 17             Isaiah Thomas
# 18                 John Wall
# 19                Kevin Love
# 20                Kyle Lowry
# 21               Paul George
# 22              Kemba Walker
# 23              Paul Millsap
# 24              LeBron James
# 25               Dwyane Wade
# 26               Paul George
# 27           Carmelo Anthony
# 28                Kyle Lowry
# 29              Jimmy Butler
#                ...
# 409             Chris Webber
# 410              Elton Brand
# 411            Allen Iverson
# 412            Tracy McGrady
# 413             Vince Carter
# 414          Alonzo Mourning
# 415               Grant Hill
# 416                Ray Allen
# 417            Antonio Davis
# 418             Theo Ratliff
# 419           Glenn Robinson
# 420         Jerry Stackhouse
# 421          Stephon Marbury
# 422            Anthony Mason
# 423          Dikembe Mutombo
# 424         Latrell Sprewell
# 425            Allan Houston
# 426               Jason Kidd
# 427              Kobe Bryant
# 428               Tim Duncan
# 429         Shaquille O'Neal
# 430             Chris Webber
# 431           Michael Finley
# 432            Kevin Garnett
# 433              Karl Malone
# 434          Antonio McDyess
# 435              Gary Payton
# 436          Rasheed Wallace
# 437           David Robinson
# 438              Vlade Divac
# Name: Player, Length: 439, dtype: object

# %%
all_star_seaons = season_stats.merge(all_stars, on = ['Player', 'Year'], how = 'left')

# %%
all_star_seaons.shape
# Out:
# (24691, 60)

# %%
all_star_seaons.tail()
# Out:
#        Unnamed: 0    Year             Player Pos_x   Age   Tm     G    GS  \
# 24686       24686  2017.0        Cody Zeller    PF  24.0  CHO  62.0  58.0
# 24687       24687  2017.0       Tyler Zeller     C  27.0  BOS  51.0   5.0
# 24688       24688  2017.0  Stephen Zimmerman     C  20.0  ORL  19.0   0.0
# 24689       24689  2017.0        Paul Zipser    SF  22.0  CHI  44.0  18.0
# 24690       24690  2017.0        Ivica Zubac     C  19.0  LAL  38.0  11.0
#
#            MP   PER     ...        TOV     PF    PTS  Pos_y   HT  WT  Team  \
# 24686  1725.0  16.7     ...       65.0  189.0  639.0    NaN  NaN NaN   NaN
# 24687   525.0  13.0     ...       20.0   61.0  178.0    NaN  NaN NaN   NaN
# 24688   108.0   7.3     ...        3.0   17.0   23.0    NaN  NaN NaN   NaN
# 24689   843.0   6.9     ...       40.0   78.0  240.0    NaN  NaN NaN   NaN
# 24690   609.0  17.0     ...       30.0   66.0  284.0    NaN  NaN NaN   NaN
#
#        Selection Type  NBA Draft Status  Nationality
# 24686             NaN               NaN          NaN
# 24687             NaN               NaN          NaN
# 24688             NaN               NaN          NaN
# 24689             NaN               NaN          NaN
# 24690             NaN               NaN          NaN
#
# [5 rows x 60 columns]

# %%
#using Team != NaN as factor for whether season stats merged with all star
all_star_seaons['AllStar']= pd.notnull(all_star_seaons.Team)

# %%
#Because we have statistics for all players from 1960- and all star data from only 2000-, let's limit the set
all_star_seasons_select = all_star_seaons[all_star_seaons.Year > 1999]

# %%
all_star_seasons_select.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos_x', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Pos_y', 'HT', 'WT', 'Team',
#        'Selection Type', 'NBA Draft Status', 'Nationality', 'AllStar'],
#       dtype='object')

# %%
all_star_seasons_select['PPG'] = all_star_seasons_select.PTS / all_star_seasons_select.G
# Out:
# /Users/christopherlee/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
features = ['Age', 'PER', 'TS%', '3PAr', 'DBPM', 'FG%', '3P', '3P%', 'TRB', 'AST', 'STL', 'BLK', 'PPG']

# %%
all_star_features = all_star_seasons_select[features].fillna(0)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
rf_model = RandomForestClassifier(n_estimators=100, max_depth=4, random_state= 100)

# %%
rf_model.fit(all_star_features, all_star_seasons_select['AllStar'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=4, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=100, verbose=0, warm_start=False)

# %%
for i in range(0, len(features)):
    print(features[i] + ": " + str(rf_model.feature_importances_[i]))
# Out:
# Age: 0.006720906978852828
# PER: 0.29325494314898526
# TS%: 0.026331158862596054
# 3PAr: 0.025356182138057803
# DBPM: 0.011404477068328032
# FG%: 0.020342949329441674
# 3P: 0.024272412512572596
# 3P%: 0.00850184026797669
# TRB: 0.06778895402057385
# AST: 0.09030736611483116
# STL: 0.06293240107447573
# BLK: 0.038118586622755427
# PPG: 0.324667821860553

# %%
sorted_feats = rf_model.feature_importances_

# %%
type(rf_model.feature_importances_)
# Out:
# numpy.ndarray

# %%
rf_model.score(all_star_features, all_star_seasons_select['AllStar'])
# Out:
# 0.9692277538220305

# %%
all_star_predictions = rf_model.predict(all_star_features)

# %%
all_star_seasons_select.reset_index(drop=True, inplace=True)

# %%
results = pd.concat([pd.Series(all_star_predictions), pd.Series(all_star_seasons_select['AllStar'])], axis=1, ignore_index=True)

# %%
results.columns = ['Predicted', 'Real']
results.groupby(["Predicted", "Real"]).size().reset_index()
# Out:
#    Predicted   Real     0
# 0      False  False  9750
# 1      False   True   278
# 2       True  False    36
# 3       True   True   140

# %%
precision = 141 / (141 + 36)
recall = 141 / (141 + 277)

# %%
[precision, recall]
# Out:
# [0.7966101694915254, 0.3373205741626794]

# %%
#explore some of the wrong ones
all_star_seasons_select[(results.Predicted == False) & (results.Real == True)]
# Out:
#       Unnamed: 0    Year                 Player Pos_x   Age   Tm     G    GS  \
# 5          14475  2000.0              Ray Allen    SG  24.0  MIL  82.0  82.0
# 118        14588  2000.0          Antonio Davis     C  31.0  TOR  79.0  78.0
# 132        14602  2000.0            Vlade Divac     C  31.0  SAC  82.0  81.0
# 152        14622  2000.0         Michael Finley    SF  26.0  DAL  82.0  82.0
# 207        14677  2000.0          Allan Houston    SG  28.0  NYK  82.0  82.0
# 251        14721  2000.0             Jason Kidd    PG  26.0  PHO  67.0  67.0
# 286        14756  2000.0        Stephon Marbury    PG  22.0  NJN  74.0  74.0
# 293        14763  2000.0          Anthony Mason    SF  33.0  CHH  82.0  81.0
# 299        14769  2000.0        Antonio McDyess    PF  25.0  DEN  81.0  81.0
# 300        14770  2000.0          Tracy McGrady    SF  20.0  TOR  79.0  34.0
# 374        14844  2000.0           Theo Ratliff    PF  26.0  PHI  57.0  56.0
# 391        14861  2000.0         Glenn Robinson    SF  27.0  MIL  81.0  81.0
# 415        14885  2000.0       Latrell Sprewell    SF  29.0  NYK  82.0  82.0
# 417        14887  2000.0       Jerry Stackhouse    SG  25.0  DET  82.0  82.0
# 464        14934  2000.0        Rasheed Wallace    PF  25.0  POR  81.0  77.0
# 498        14969  2001.0    Shareef Abdur-Rahim    SF  24.0  VAN  81.0  81.0
# 464    1995 Rnd 1 Pick 4                      United States     True
# 498    1996 Rnd 1 Pick 3                      United States     True
# 546    1999 Rnd 1 Pick 1                      United States     True
# 610    1999 Rnd 1 Pick 3                      United States     True
# 656    1999 Rnd 1 Pick 2                      United States     True
# 748    1994 Rnd 1 Pick 2                      United States     True
# 849   1996 Rnd 1 Pick 15               Canada\nSouth Africa     True
# 858   1996 Rnd 1 Pick 17                      United States     True
# 961   1996 Rnd 1 Pick 14                     Serbia\nGreece     True
# 976    1999 Rnd 1 Pick 6               United States\nSpain     True
# 998    1996 Rnd 1 Pick 6                      United States     True
# 1120   1998 Rnd 1 Pick 5                      United States     True
# 1192   1999 Rnd 1 Pick 2                      United States     True
# 1248  1996 Rnd 1 Pick 20                          Lithuania     True
# 1282   1994 Rnd 1 Pick 2                      United States     True
# 1312   1996 Rnd 1 Pick 4                      United States     True
# ...                  ...                                ...      ...
# 8467  2011 Rnd 1 Pick 30                      United States     True
# 8537   2009 Rnd 1 Pick 9                      United States     True
# 8551   2012 Rnd 1 Pick 9                      United States     True
# 8555   2007 Rnd 1 Pick 2                      United States     True
# 8589   2001 Rnd 1 Pick 3                              Spain     True
# 8594  2010 Rnd 1 Pick 10                      United States     True
# 8608   2012 Rnd 2 Pick 5                      United States     True
# 8654   2007 Rnd 1 Pick 3  Dominican Republic\nUnited States     True
# 8727  2011 Rnd 1 Pick 15                      United States     True
# 8736  2006 Rnd 1 Pick 24                      United States     True
# 8779  2006 Rnd 2 Pick 17                      United States     True
# 8951  2011 Rnd 2 Pick 30                      United States     True
# 8952  2011 Rnd 2 Pick 30                      United States     True
# 8953  2011 Rnd 2 Pick 30                      United States     True
# 8961  2011 Rnd 1 Pick 11                      United States     True
# 8981   2003 Rnd 1 Pick 5                      United States     True
# 8987   2010 Rnd 1 Pick 1                      United States     True
# 9051  2013 Rnd 1 Pick 15                    Greece\nNigeria     True
# 9157   2009 Rnd 1 Pick 9                      United States     True
# 9202  2007 Rnd 2 Pick 18                              Spain     True
# 9219   2012 Rnd 2 Pick 5                      United States     True
# 9250   2010 Rnd 1 Pick 9                      United States     True
# 9292   2011 Rnd 1 Pick 1           United States\nAustralia     True
# 9323   2008 Rnd 2 Pick 5                      United States     True
# 9362   2008 Rnd 1 Pick 5                      United States     True
# 9406  2006 Rnd 2 Pick 17                      United States     True
# 9541  2011 Rnd 2 Pick 30                      United States     True
# 9547  2011 Rnd 1 Pick 11                      United States     True
# 9573   2011 Rnd 1 Pick 9                      United States     True
# 9574   2010 Rnd 1 Pick 1                      United States     True
#
#             PPG
# 5     22.060976
# 118   11.518987
# 132   12.256098
# 152   22.621951
# 207   19.682927
# 251   14.313433
# 286   22.162162
# 293   11.560976
# 299   19.148148
# 300   15.354430
# 374   11.859649
# 391   20.901235
# 415   18.585366
# 417   23.646341
# 464   16.358025
# 498   20.530864
# 546   20.135135
# 610   13.792683
# 656   19.887500
# 748   16.870130
# 849   15.600000
# 858   12.851852
# 961   20.386667
# 976   13.963415
# 998   23.358025
# 1120  24.733333
# 1192  21.649123
# 1248  11.129032
# 1282  14.731707
# 1312  20.414634
# ...         ...
# 8467  20.015385
# 8537  20.066667
# 8551  13.780488
# 8555  25.407407
# 8589  18.538462
# 8594   8.833333
# 8608  11.658228
# 8654  15.210526
# 8727  16.515625
# 8736  17.771429
# 8779  16.684932
# 8951  16.432836
# 8952  15.239130
# 8953  19.047619
# 8961  21.662338
# 8981  21.467742
# 8987  17.556962
# 9051  16.875000
# 9157  23.461538
# 9202  16.557692
# 9219  13.962963
# 9250  19.725000
# 9292  19.641509
# 9323  12.727273
# 9362  16.025974
# 9406  17.098765
# 9541  22.231707
# 9547  22.137500
# 9573  20.851852
# 9574  19.883117
#
# [278 rows x 62 columns]

# %%
all_star_seasons_select.Pos_x.value_counts()
# Out:
# PF       2080
# PG       2073
# C        2035
# SG       1974
# SF       1887
# PG-SG      25
# C-PF       23
# SF-SG      18
# SG-SF      18
# SG-PG      18
# PF-SF      17
# SF-PF      16
# PF-C       15
# SG-PF       3
# PG-SF       1
# C-SF        1
# Name: Pos_x, dtype: int64

# %%
position_dict = {'C-SF': 'SF', 'PG-SG': 'PG', 'C-PF': 'C', 'SG-PG': 'SG', 'SG-SF': 'SG',
                'SF-SG': 'SF', 'PF-SF': 'PF', 'SF-PF': 'SF', 'PF-C': 'PF', 'SG-PF': 'SG', 'PG-SF': 'PG'}

# %%
all_star_seasons_select['Pos1'] = all_star_seasons_select.Pos_x.map(position_dict).fillna(all_star_seasons_select.Pos_x)
# Out:
# /Users/christopherlee/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Create new dataframe with only 5 positions

# %%
all_star_features2 = all_star_features
all_star_features2['Pos'] = all_star_seasons_select.Pos1

# %%
all_star_features2 = pd.get_dummies(all_star_features2, columns = ['Pos'])

# %%
rf_position = RandomForestClassifier(n_estimators=100, max_depth=4, random_state= 100)
rf_position.fit(all_star_features2, all_star_seasons_select['AllStar'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=4, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=100, verbose=0, warm_start=False)

# %%
for i in range(0, all_star_features2.shape[1]):
    print(all_star_features2.columns[i] + ": " + str(rf_position.feature_importances_[i]))
# Out:
# Age: 0.006720906978852828
# PER: 0.29325494314898526
# TS%: 0.026331158862596054
# 3PAr: 0.025356182138057803
# DBPM: 0.011404477068328032
# FG%: 0.020342949329441674
# 3P: 0.024272412512572596
# 3P%: 0.00850184026797669
# TRB: 0.06778895402057385
# AST: 0.09030736611483116
# STL: 0.06293240107447573
# BLK: 0.038118586622755427
# PPG: 0.324667821860553

# %%
all_star_predictions2 = rf_position.predict(all_star_features2)

# %%
results2 = pd.concat([pd.Series(all_star_predictions2), pd.Series(all_star_seasons_select['AllStar'])], axis=1, ignore_index=True)
results2.columns = ['Predicted', 'Real']
results2.groupby(["Predicted", "Real"]).size().reset_index()
# Out:
#    Predicted   Real     0
# 0      False  False  9750
# 1      False   True   278
# 2       True  False    36
# 3       True   True   140

# %%
random.seed()
